# %% [markdown]
# # conditionals and boolenas

# %%
if True:
  print("true come when condition are true")
# Out:
# true come when condition are true

# %%
if False:
  print("true come when condition are true")

# %%
language = 'Python'
if language == 'Python':
  print("condtion is true")
# Out:
# condtion is true

# %%
# comparsions 
#equal:==
#not equal:!=
#greater than:>
#less than:<
#object identity: is

# %%
language = 'Java'
if language == 'Python':
  print("Language is python")
elif language == 'Java':
  print("Language is Java")
elif language == 'c':
  print("Language is c")
else:
    print("no match")
# Out:
# Language is Java

# %%
# and
# or
#not

# %%
user = 'Admin'
logged_in = True

if user =='Admin' and logged_in:
  print("Admin page")
else:
  print('Bad creds')
# Out:
# Admin page

# %%
user = 'Admin'
logged_in = False

if user =='Admin' and logged_in:
  print("Admin page")
else:
  print('Bad creds')
# Out:
# Bad creds

# %%
user = 'Admin'
logged_in = True

if user =='Admin' or logged_in:
  print("Admin page")
else:
  print('Bad creds')
# Out:
# Admin page

# %%
user ='admin'
logged_in = False

if not logged_in:
  print('Please log in')
else:
  print('welcome')
# Out:
# Please log in

# %%
user ='admin'
logged_in = True

if not logged_in:
  print('Please log in')
else:
  print('welcome')
# Out:
# welcome

# %%
#False Values:
#false
#none
#zero of any numeric type
#any empty sequence for example, '' ,() ,[].
#any empty mapping for example, {}

condition = False

if condition:
  print('Evaluated to true')
else:
  print('Evaluated to False')
# Out:
# Evaluated to False

# %%
condition = None

if condition:
  print('Evaluated to true')
else:
  print('Evaluated to False')
# Out:
# Evaluated to False

# %%
condition = 10

if condition:
  print('Evaluated to true')
else:
  print('Evaluated to False')
# Out:
# Evaluated to true

# %%
condition = 0

if condition:
  print('Evaluated to true')
else:
  print('Evaluated to False')
# Out:
# Evaluated to False

# %%
condition = ''

if condition:
  print('Evaluated to true')
else:
  print('Evaluated to False')
# Out:
# Evaluated to False

# %%
condition = {}

if condition:
  print('Evaluated to true')
else:
  print('Evaluated to False')
# Out:
# Evaluated to False

# %%
condition = ()

if condition:
  print('Evaluated to true')
else:
  print('Evaluated to False')
# Out:
# Evaluated to False

# %%
condition = 'Test'

if condition:
  print('Evaluated to true')
else:
  print('Evaluated to False')
# Out:
# Evaluated to true

# %%
a = [1,2,3]
b = [1,2,3]

print(id(a))
print(id(b))
print(a is b)
# Out:
# 2308524680000
# 2308524540864
# False

# %%
a = [1,2,3]
b = a

print(id(a))
print(id(b))
print(id(a) == id(b))
# Out:
# 2308524262784
# 2308524262784
# True
