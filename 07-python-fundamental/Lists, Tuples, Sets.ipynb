# %% [markdown]
# # Lists, Tuples, Sets

# %%
# list use square box[]
# we .append() .extend() .insert() .remove().pop()

course = ['History','math','physics','computerscience']
print(course[-1])
print(course[2])
print(course[0:3])
course.append('Java')#add elemnt at end
print(course)
course.insert(4,'Python')#add element to particular position
print(course)
couser_1 = ['c++','Javascrpit']
course.extend(course)# use tho add multiple value
print(course)
popped = course.pop()# delet the last elemnt
print(popped)
print(course)
course.reverse()
print(course)
print(course.index('math'))#to find index value in list we use .index()
print('math' in course)
print('c' in course)
# Out:
# computerscience
# physics
# ['History', 'math', 'physics']
# ['History', 'math', 'physics', 'computerscience', 'Java']
# ['History', 'math', 'physics', 'computerscience', 'Python', 'Java']
# ['History', 'math', 'physics', 'computerscience', 'Python', 'Java', 'History', 'math', 'physics', 'computerscience', 'Python', 'Java']
# Java
# ['History', 'math', 'physics', 'computerscience', 'Python', 'Java', 'History', 'math', 'physics', 'computerscience', 'Python']
# ['Python', 'computerscience', 'physics', 'math', 'History', 'Java', 'Python', 'computerscience', 'physics', 'math', 'History']
# 3
# True
# False

# %%
#sort()arrange the number or alphabeths in alphabet way in correct
number = [1,4,5,3,6,7,2,9]
course = ['History','math','physics','computerscience']
sorted(course)
print(course)
number.sort(reverse=True)
course.sort(reverse=True)
print(course)
print(number)
# Out:
# ['History', 'math', 'physics', 'computerscience']
# ['physics', 'math', 'computerscience', 'History']
# [9, 7, 6, 5, 4, 3, 2, 1]

# %%
number = [1,4,5,3,6,7,2,9]
#usin min(),max(),sum()bulit in function
print(min(number))
print(max(number))
print(sum(number))
# Out:
# 1
# 9
# 37

# %%
course = ['History','math','physics','computerscience']

for item in course:
  print(item)
# Out:
# History
# math
# physics
# computerscience

# %%
for index,course in enumerate(course):
  print(index,course)
# Out:
# 0 History
# 1 math
# 2 physics
# 3 computerscience

# %%
course = ['History','math','physics','computerscience']
course_str = '-'.join(course)
print(course_str)
new_list = course_str.split('-')
print(new_list)
# Out:
# History-math-physics-computerscience
# ['History', 'math', 'physics', 'computerscience']

# %%
#sets are unordered and no duplicates allow
course = {'History','math','physics','computerscience'}
print(course)
# Out:
# {'math', 'History', 'computerscience', 'physics'}

# %%
course = {'History','math','physics','computerscience'}
art_course = {'History','math','art','design'}
print(course.intersection(art_course))
print(course.difference(art_course))
print(course.union(art_course))
# Out:
# {'math', 'History'}
# {'computerscience', 'physics'}
# {'History', 'computerscience', 'design', 'physics', 'math', 'art'}

# %%
#empty list
empty_list = []
empty_list = list()

#empty tuple
empty_tuple = ()
empty_tuple = tuple()

#empty sets
empty_dict = {}
empty_sets = set()

# %% [markdown]
# # practice

# %%
list =['apple','banana','pineappe','papya','graphes']
list.append('Mango')
print(list)
list.insert(2,'orange')
print(list)
l1=['pomogranet','strawberry']
list.extend(l1)
print(list)
list.remove('apple')
print(list)
list.pop()
print(list)
# Out:
# ['apple', 'banana', 'pineappe', 'papya', 'graphes', 'Mango']
# ['apple', 'banana', 'orange', 'pineappe', 'papya', 'graphes', 'Mango']
# ['apple', 'banana', 'orange', 'pineappe', 'papya', 'graphes', 'Mango', 'pomogranet', 'strawberry']
# ['banana', 'orange', 'pineappe', 'papya', 'graphes', 'Mango', 'pomogranet', 'strawberry']
# ['banana', 'orange', 'pineappe', 'papya', 'graphes', 'Mango', 'pomogranet']

# %%
num=[1,2,3,4,5,8,5]
num.sort()
print(num)
num.sort(reverse=True)
print(num)
# Out:
# [1, 2, 3, 4, 5, 5, 8]
# [8, 5, 5, 4, 3, 2, 1]

# %%
number = []
for i in range(5):
  num = int(input(f"Enter number{i+1}: "))
  number.append(num)
print("the list is :",number)
print(min(number))
print(max(number))
print("sum",sum(number))
avg=sum(number)/len(number)
print(avg)
# Out:
# the list is : [1, 2, 3, 4, 5]
# 1
# 5
# sum 15
# 3.0

# %%
l2= [1, 2, 3, 4, 5]

# %%
for i in l2:
  if i%2==0:
    print(i,"Even")
  else:
     print("odd")
# Out:
# odd
# 2 Even
# odd
# 4 Even
# odd

# %%
l2 = [1, 2, 3, 4, 5]

for i in l2:
    if i % 2 != 0:
        print(i)
# Out:
# 1
# 3
# 5

# %%
numbers = [10, 20, 40, 50, 30]

numbers.sort()

print("Second largest number:", numbers[-2])
# Out:
# Second largest number: 40

# %%
list = [1,2,3,4,4,5,6,6,7,8,8]
unique = []
for i in list:
  if i not in unique:
    unique.append(i)
  print("original list:",list)
  print("remove duplicate:",unique)
# Out:
# original list: [1, 2, 3, 4, 4, 5, 6, 6, 7, 8, 8]
# remove duplicate: [1]
# original list: [1, 2, 3, 4, 4, 5, 6, 6, 7, 8, 8]
# remove duplicate: [1, 2]
# original list: [1, 2, 3, 4, 4, 5, 6, 6, 7, 8, 8]
# remove duplicate: [1, 2, 3]
# original list: [1, 2, 3, 4, 4, 5, 6, 6, 7, 8, 8]
# remove duplicate: [1, 2, 3, 4]
# original list: [1, 2, 3, 4, 4, 5, 6, 6, 7, 8, 8]
# remove duplicate: [1, 2, 3, 4]
# original list: [1, 2, 3, 4, 4, 5, 6, 6, 7, 8, 8]
# remove duplicate: [1, 2, 3, 4, 5]
# original list: [1, 2, 3, 4, 4, 5, 6, 6, 7, 8, 8]
# remove duplicate: [1, 2, 3, 4, 5, 6]
# original list: [1, 2, 3, 4, 4, 5, 6, 6, 7, 8, 8]
# remove duplicate: [1, 2, 3, 4, 5, 6]
# original list: [1, 2, 3, 4, 4, 5, 6, 6, 7, 8, 8]
# remove duplicate: [1, 2, 3, 4, 5, 6, 7]
# original list: [1, 2, 3, 4, 4, 5, 6, 6, 7, 8, 8]
# remove duplicate: [1, 2, 3, 4, 5, 6, 7, 8]
# original list: [1, 2, 3, 4, 4, 5, 6, 6, 7, 8, 8]
# remove duplicate: [1, 2, 3, 4, 5, 6, 7, 8]

# %%
numbers = [10, 15, 20, 25, 30, 35]

even = 0
odd = 0

for i in numbers:
    if i % 2 == 0:
        even += 1
    else:
        odd += 1

print("Even numbers:", even)
print("Odd numbers:", odd)
# Out:
# Even numbers: 3
# Odd numbers: 3

# %%
numbers = [10, 15, 20, 25, 30, 35]
reverse =numbers[::-1]
print(reverse)
# Out:
# [35, 30, 25, 20, 15, 10]

# %%
numbers = [10, 20, 40, 50, 30]

numbers.sort()

print("Smallest number:", numbers[0])
# Out:
# Smallest number: 10

# %%
numbers = [10, 20, 40, 50, 30]

numbers.sort()

print("Second smalles number:", numbers[1])
# Out:
# Second smalles number: 20

# %%
numbers = [10, 20, 40, 50, 30]

numbers.sort()

print(" largest number:", numbers[-1])
# Out:
#  largest number: 50

# %%
numbers = [10, 20, 40, 50, 30]

print("Sum",sum(numbers))
# Out:
# Sum 150

# %%
numbers = [10, 20, 40, 50, 30]

print("Sum",sum(numbers))
avg = sum(numbers)/len(numbers)
print(avg)
# Out:
# Sum 150
# 30.0

# %%
numbers = [10, 20, 40, 50, 30]
numbers[0]
numbers[::-1]
numbers[1]
# Out:
# 20

# %%
a=[1,2,3]
b=[4,5,6]
print(a+b)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
numbers = [10, 20, 30, 40, 50]

numbers = numbers[1:] + numbers[:1]

print("After left rotation:", numbers)
# Out:
# After left rotation: [20, 30, 40, 50, 10]

# %%
numbers = [10, 20, 30, 40, 50]

search = int(input("Enter number to search: "))

if search in numbers:
    print(search, "is found in the list")
else:
    print(search, "is not found in the list")
# Out:
# 2 is not found in the list
