# %% [markdown]
# # Intergers and floats

# %%
num = 3
#type()method is used to get know the data type of a variable
print(type(num))
# Out:
# <class 'int'>

# %%
# Arthmetic operations:
#add 3+2
#subtract 3-2
#multiply 3*2
#division 3/2
#floor division 3//2
#exponent 3**2
#modulus 3%2

# %%
num = 1
num *=10
print(num)
# Out:
# 10

# %%
#absolute value means the distance  of a number from zero.it is alwasys positive.we can use abs() method to get the absolute value of a number.
print(abs(-3))
print(abs(-15))
# Out:
# 3
# 15

# %%
#round()method is used to round a number to the nearest integer.
print(round(3.75,1))
print(round(4.95))
# Out:
# 3.8
# 5

# %%
#comparision operators are used to compare two values and return a boolean values
#Equal: 3==2
#not equal:3!=2
#greater than:3>2
#less than:3<2
#greater or equal:3>=2
#less or equal 3<=2

# %%
num_1 = 3
num_2 = 2
print(num_1==num_2)
print(num_1 != num_2)
# Out:
# False
# True

# %%
a=int(input("enter a number:"))

if a%2==1:
  print(a," are odd")
else:
  print(a," is even")
# Out:
# 9  are odd

# %% [markdown]
# # Practice

# %%
#Check whether a number is positive or negative.
a = int(input("Enter the number:"))
if a>=0:
  print(a,"is positive number")
else:
  print(a,"is negative")
# Out:
# -3 is negative

# %%
#Check whether a number is even or odd.
a=int(input("enter a number:"))

if a%2==1:
  print(a," are odd")
else:
  print(a," is even")
# Out:
# 4  is even

# %%
age = int(input("enter your age:"))
if age>=18:
  print(age,"are eligible for voting")
else:
  print(age,"are not eligilbe for voting")
# Out:
# 15 are not eligilbe for voting

# %%
student_mark=int(input("Enter the student mark:"))
if student_mark>=35:
  print(student_mark,"is passed in maths subject")
else:
  print("Fail in math")
# Out:
# Fail in math

# %%
number=int(input("Enter the number:"))
if number %5==0:
  print(number,"divisible by 5")
else:
  print(number,"is not divisible")
# Out:
# 6 is not divisible

# %%
number=int(input("enter the number"))
if number%3==0 and number%5==0:
  print(number,"is divisible  by both 3 and 5")
else:
  print(number,"is not divisible")
# Out:
# 12 is not divisible

# %%
number=int(input("enter the number"))
if number%10==0:
  print(number,"is multiple of 10")
else:
  print(number,"is not multipe")
# Out:
# 15 is not multipe

# %%
a=str(input("enter the letter"))
if a in "aeiou":
  print(a,"is vowel")
else:
  print(a,"is consonent")
# Out:
# f is consonent

# %%
name=input("enter the name:")
age=int(input("enter our age :"))
percentage=float(input("enter your percentage"))

if age>=18:
  print(age,"is eligible for voting")
else: 
  print(age,"is not eligible")
  if percentage<=60:
      print(percentage,"student is fail")
  else:
      print(percentage,"Student is pass")
# Out:
# 12 is not eligible
# 56.0 student is fail

# %%
print("Bill Split Calculator")
bill_amount=float(input())
tip_percentage=float(input())
Split_bill=int(input())

tip_amount=(tip_percentage /100)*bill_amount
total_amount=bill_amount+tip_amount
amount_person=total_amount/Split_bill

print(f"Total (including tip): ${total_amount}")
print(f"Each person pays: ${amount_person}")
# Out:
# Bill Split Calculator
# Total (including tip): $75.15
# Each person pays: $0.9634615384615385

# %%
# Simple Calculator in Python

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Choose operation:")
print("1. Addition (+)")
print("2. Subtraction (-)")
print("3. Multiplication (*)")
print("4. Division (/)")

choice = input("Enter choice (1/2/3/4): ")

if choice == '1':
    print("Result:", num1 + num2)

elif choice == '2':
    print("Result:" ,{num1 + num2} , num1 - num2)

elif choice == '3':
    print("Result:", num1 * num2)

elif choice == '4':
    if num2 != 0:
        print("Result:", num1 / num2)
    else:
        print("Error: Division by zero")

else:
    print("Invalid choice")
# Out:
# Choose operation:
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# Result: 48.0

# %%
m1= int(input('Enter the marks in subject1'))
m2= int(input('Enter the marks in subject2'))
m3= int(input('Enter the marks in subject3'))
avg=(m1+m2+m3)/3
if avg>=90:
    print('Grade A')
elif avg>=75 and avg<90:
    print('Grade B')
elif avg>=60 and avg<75:
    print('Grade C')
else:
    print('Grade D')

# %%
# Grade Calculator with Input Validation

name = input("Enter the student name: ")
marks_obtained = float(input("Enter marks obtained: "))
total_marks = float(input("Enter total marks allotted: "))

if marks_obtained < 0 or total_marks <= 0:
    print("Invalid input! Marks cannot be negative or zero.")
elif marks_obtained > total_marks:
    print("Invalid input! Marks obtained cannot exceed total marks.")
else:
    percentage = (marks_obtained / total_marks) * 100
    print("Percentage = {:.2f}".format(percentage))

    if percentage >= 90:
        print(name, "Outstanding performance - O")
    elif percentage >= 80:
        print(name, "Exemplary performance - A++")
    elif percentage >= 70:
        print(name, "Distinction - A+")
    elif percentage >= 60:
        print(name, "First Class - A")
    elif percentage >= 50:
        print(name, "Second Class - B+")
    elif percentage >= 35:
        print(name, "Pass")
    else:
        print(name, "Fail")
# Out:
# Percentage = 87.08
# swathi Exemplary performance - A++
